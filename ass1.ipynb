# %%
import pandas as pd

# %%
data= pd.read_csv('dataset_Facebook.csv', sep=';')

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
subset1 =data[['comment','like','share'] ]

# %%
subset1
# Out:
#      comment    like  share
# 0          4    79.0   17.0
# 1          5   130.0   29.0
# 2          0    66.0   14.0
# 3         58  1572.0  147.0
# 4         19   325.0   49.0
# ..       ...     ...    ...
# 495        5    53.0   26.0
# 496        0    53.0   22.0
# 497        4    93.0   18.0
# 498        7    91.0   38.0
# 499        0    91.0   28.0
#
# [500 rows x 3 columns]

# %%
subset1.sort_values('comment', ascending= True)
# Out:
#      comment    like  share
# 499        0    91.0   28.0
# 111        0     NaN    NaN
# 276        0    25.0    5.0
# 282        0   104.0   13.0
# 286        0    15.0    3.0
# ..       ...     ...    ...
# 228       64   367.0   25.0
# 288      103   469.0   33.0
# 168      144  1622.0  208.0
# 460      146  1546.0  181.0
# 244      372  5172.0  790.0
#
# [500 rows x 3 columns]

# %%
subset1.sort_values('like', ascending= False)
# Out:
#      comment    like  share
# 244      372  5172.0  790.0
# 379       51  1998.0  128.0
# 349       45  1639.0  122.0
# 168      144  1622.0  208.0
# 3         58  1572.0  147.0
# ..       ...     ...    ...
# 21         0     0.0    0.0
# 100        0     0.0    0.0
# 441        0     0.0    0.0
# 417        0     0.0    0.0
# 111        0     NaN    NaN
#
# [500 rows x 3 columns]

# %%
subset2= data[['Page total likes', 'Type', 'share']]

# %%
subset2
# Out:
#      Page total likes    Type  share
# 0              139441   Photo   17.0
# 1              139441  Status   29.0
# 2              139441   Photo   14.0
# 3              139441   Photo  147.0
# 4              139441   Photo   49.0
# ..                ...     ...    ...
# 495             85093   Photo   26.0
# 496             81370   Photo   22.0
# 497             81370   Photo   18.0
# 498             81370   Photo   38.0
# 499             81370   Photo   28.0
#
# [500 rows x 3 columns]

# %%
pd.merge(subset1, subset2)
# Out:
#       comment    like  share  Page total likes    Type
# 0           4    79.0   17.0            139441   Photo
# 1           4    79.0   17.0            138414  Status
# 2           4    79.0   17.0            138458   Photo
# 3           4    79.0   17.0            138895   Photo
# 4           4    79.0   17.0            138895   Photo
# ...       ...     ...    ...               ...     ...
# 5145      146  1546.0  181.0             92507   Photo
# 5146       19   214.0   78.0             92293   Photo
# 5147       56   360.0   99.0             86909   Photo
# 5148       21   277.0   80.0             85979   Photo
# 5149        1   105.0   46.0             85979   Photo
#
# [5150 rows x 5 columns]

# %%
df= data.transpose()

# %%
df
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df.shape
# Out:
# (19, 500)

# %%
a= data.iloc[1:50:3]

# %%
a
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 4             139441   Photo         2          12             2          3
# 7             139441   Photo         3          12             7          9
# 10            139441  Status         2          12             5         10
# 13            139441   Photo         2          12             5          3
# 16            138414   Photo         3          12             3          3
# 19            138414   Photo         3          12             1         11
# 22            138414    Link         1          12             7         10
# 25            138458  Status         2          12             6          3
# 28            138895   Photo         2          12             5          3
# 31            138895   Photo         2          12             3         10
# ...

# %%
a.shape
# Out:
# (17, 19)

# %%
table=pd.pivot_table(data = data, index= ['Total Interactions'], columns=['Type'],values=['like'])

# %%
table
# Out:
#                    like
# Type               Link   Photo Status Video
# Total Interactions
# 0                   NaN     0.0    NaN   NaN
# 2                   NaN     2.0    NaN   NaN
# 3                   NaN     3.0    NaN   NaN
# 4                   NaN     2.5    NaN   NaN
# 5                   NaN     4.0    NaN   NaN
# ...                 ...     ...    ...   ...
# 1806                NaN  1639.0    NaN   NaN
# 1873                NaN  1546.0    NaN   NaN
# 1974                NaN  1622.0    NaN   NaN
# 2177                NaN  1998.0    NaN   NaN
# 6334                NaN  5172.0    NaN   NaN
#
# [280 rows x 4 columns]

# %%
table.shape
# Out:
# (280, 4)
