# %% [markdown]
# (GROUP - B) ASSIGNMENT - 2:
#
# Perform the following operations using Python on the Air quality and Heart Diseases data sets
#
# a. Data cleaning
#
# b. Data integration
#
# c. Data transformation
#
# d. Error correcting
#
# e. Data model building

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv("AirQuality.csv")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data1
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP          24-12-2015                  West Bengal   ULUBERIA
# 435738     SAMP          29-12-2015                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
data2 = pd.read_csv("heart.csv")
data2
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
data1.shape
# Out:
# (435742, 13)

# %%
data2.shape
# Out:
# (303, 15)

# %%
data1.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
data1['stn_code']=data1['stn_code'].fillna(0)
data1
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP          24-12-2015                  West Bengal   ULUBERIA
# 435738     SAMP          29-12-2015                  West Bengal   ULUBERIA
# 435739        0                 NaN  andaman-and-nicobar-islands        NaN
# 435740        0                 NaN                  Lakshadweep        NaN
# 435741        0                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
data2.fillna(0)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
data1.isnull().sum()
# Out:
# stn_code                            0
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
data1= data1.drop('agency',axis=1)
data1
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP          24-12-2015                  West Bengal   ULUBERIA
# 435738     SAMP          29-12-2015                  West Bengal   ULUBERIA
# 435739        0                 NaN  andaman-and-nicobar-islands        NaN
# 435740        0                 NaN                  Lakshadweep        NaN
# 435741        0                 NaN                      Tripura        NaN
#
# ...

# %%
data1.type.unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area', nan,
#        'Sensitive Area', 'Residential and other Areas',
#        'Residential Area', 'RIRUO'], dtype=object)

# %%
data1['type'] = data1['type'].replace(['Industrial Areas','Residential and others','Sensitive Areas','Industrial','Residential','Sensitive'],['Industrial Area','Residential and other Areas','Sensitive Area','Industrial Area','Residential Area','Sensitive Area'])

# %%
data1.type.unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area', nan,
#        'Sensitive Area', 'Residential and other Areas',
#        'Residential Area', 'RIRUO'], dtype=object)

# %%
data1['so2'].fillna(int(data1['so2'].mean()), inplace=True)

# %%
data1['no2'].fillna(int(data1['no2'].mean()), inplace=True)

# %%
data1['rspm'].fillna(int(data1['rspm'].mean()), inplace=True)

# %%
data1['spm'].fillna(int(data1['spm'].mean()), inplace=True)

# %%
data1['pm2_5'].fillna(int(data1['pm2_5'].mean()), inplace=True)

# %%
data1.isnull().sum()
# Out:
# stn_code                           0
# sampling_date                      3
# state                              0
# location                           3
# type                            5393
# so2                                0
# no2                                0
# rspm                               0
# spm                                0
# location_monitoring_station    27491
# pm2_5                              0
# date                               7
# dtype: int64

# %%
data3=data1.rename(columns={"date":"year"})
data3
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP          24-12-2015                  West Bengal   ULUBERIA
# 435738     SAMP          29-12-2015                  West Bengal   ULUBERIA
# 435739        0                 NaN  andaman-and-nicobar-islands        NaN
# 435740        0                 NaN                  Lakshadweep        NaN
# 435741        0                 NaN                      Tripura        NaN
#
# ...

# %%
data2.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
data2['Sex']=data2['Sex'].replace([0,1],['female','male'])
data2
# Out:
#      Unnamed: 0  Age     Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    male       typical     145   233    1        2    150
# 1             2   67    male  asymptomatic     160   286    0        2    108
# 2             3   67    male  asymptomatic     120   229    0        2    129
# 3             4   37    male    nonanginal     130   250    0        0    187
# 4             5   41  female    nontypical     130   204    0        2    172
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 298         299   45    male       typical     110   264    0        0    132
# 299         300   68    male  asymptomatic     144   193    1        0    141
# 300         301   57    male  asymptomatic     130   131    0        0    115
# 301         302   57  female    nontypical     130   236    0        2    174
# 302         303   38    male    nonanginal     138   175    0        0    173
#
# ...

# %%
data2['ChestPain']=data2['ChestPain'].replace([0,1,2,3],['typical angina','atypical angina','non-anginal pain','asymptomatic'])
data2
# Out:
#      Unnamed: 0  Age     Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    male       typical     145   233    1        2    150
# 1             2   67    male  asymptomatic     160   286    0        2    108
# 2             3   67    male  asymptomatic     120   229    0        2    129
# 3             4   37    male    nonanginal     130   250    0        0    187
# 4             5   41  female    nontypical     130   204    0        2    172
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 298         299   45    male       typical     110   264    0        0    132
# 299         300   68    male  asymptomatic     144   193    1        0    141
# 300         301   57    male  asymptomatic     130   131    0        0    115
# 301         302   57  female    nontypical     130   236    0        2    174
# 302         303   38    male    nonanginal     138   175    0        0    173
#
# ...

# %%
data2['ExAng']=data2['ExAng'].replace([0,1],['no','yes'])
data2
# Out:
#      Unnamed: 0  Age     Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    male       typical     145   233    1        2    150
# 1             2   67    male  asymptomatic     160   286    0        2    108
# 2             3   67    male  asymptomatic     120   229    0        2    129
# 3             4   37    male    nonanginal     130   250    0        0    187
# 4             5   41  female    nontypical     130   204    0        2    172
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 298         299   45    male       typical     110   264    0        0    132
# 299         300   68    male  asymptomatic     144   193    1        0    141
# 300         301   57    male  asymptomatic     130   131    0        0    115
# 301         302   57  female    nontypical     130   236    0        2    174
# 302         303   38    male    nonanginal     138   175    0        0    173
#
# ...

# %%
data2['Slope']=data2['Slope'].replace([0,1,2],['upsloping','flat','downsloping'])
data2
# Out:
#      Unnamed: 0  Age     Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    male       typical     145   233    1        2    150
# 1             2   67    male  asymptomatic     160   286    0        2    108
# 2             3   67    male  asymptomatic     120   229    0        2    129
# 3             4   37    male    nonanginal     130   250    0        0    187
# 4             5   41  female    nontypical     130   204    0        2    172
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 298         299   45    male       typical     110   264    0        0    132
# 299         300   68    male  asymptomatic     144   193    1        0    141
# 300         301   57    male  asymptomatic     130   131    0        0    115
# 301         302   57  female    nontypical     130   236    0        2    174
# 302         303   38    male    nonanginal     138   175    0        0    173
#
# ...

# %%
data2['Thal']=data2['Thal'].replace([0,1,2,3],['nan','normal','fixed defect','reversable defect'])
data2
# Out:
#      Unnamed: 0  Age     Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    male       typical     145   233    1        2    150
# 1             2   67    male  asymptomatic     160   286    0        2    108
# 2             3   67    male  asymptomatic     120   229    0        2    129
# 3             4   37    male    nonanginal     130   250    0        0    187
# 4             5   41  female    nontypical     130   204    0        2    172
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 298         299   45    male       typical     110   264    0        0    132
# 299         300   68    male  asymptomatic     144   193    1        0    141
# 300         301   57    male  asymptomatic     130   131    0        0    115
# 301         302   57  female    nontypical     130   236    0        2    174
# 302         303   38    male    nonanginal     138   175    0        0    173
#
# ...

# %%
data2['Fbs']=data2['Fbs'].replace([0,1],['false','true'])
data2
# Out:
#      Unnamed: 0  Age     Sex     ChestPain  RestBP  Chol    Fbs  RestECG  \
# 0             1   63    male       typical     145   233   true        2
# 1             2   67    male  asymptomatic     160   286  false        2
# 2             3   67    male  asymptomatic     120   229  false        2
# 3             4   37    male    nonanginal     130   250  false        0
# 4             5   41  female    nontypical     130   204  false        2
# ..          ...  ...     ...           ...     ...   ...    ...      ...
# 298         299   45    male       typical     110   264  false        0
# 299         300   68    male  asymptomatic     144   193   true        0
# 300         301   57    male  asymptomatic     130   131  false        0
# 301         302   57  female    nontypical     130   236  false        2
# 302         303   38    male    nonanginal     138   175  false        0
#
#      MaxHR ExAng  Oldpeak        Slope   Ca        Thal  AHD
# ...

# %%
data2['RestECG']=data2['RestECG'].replace([0,1,2],['normal','having ST-T wave abnormality','showing probable or definite left ventricular hypertrophy by Estes’ criteria'])
data2
# Out:
#      Unnamed: 0  Age     Sex     ChestPain  RestBP  Chol    Fbs  \
# 0             1   63    male       typical     145   233   true
# 1             2   67    male  asymptomatic     160   286  false
# 2             3   67    male  asymptomatic     120   229  false
# 3             4   37    male    nonanginal     130   250  false
# 4             5   41  female    nontypical     130   204  false
# ..          ...  ...     ...           ...     ...   ...    ...
# 298         299   45    male       typical     110   264  false
# 299         300   68    male  asymptomatic     144   193   true
# 300         301   57    male  asymptomatic     130   131  false
# 301         302   57  female    nontypical     130   236  false
# 302         303   38    male    nonanginal     138   175  false
#
#                                                RestECG  MaxHR ExAng  Oldpeak  \
# 0    showing probable or definite left ventricular ...    150    no      2.3
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    object
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    object
#  7   RestECG     303 non-null    object
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    object
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    object
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 35.6+ KB

# %%
data2.Ca.unique()
# Out:
# array([ 0.,  3.,  2.,  1., nan])

# %%
data2['Ca'].value_counts()
# Out:
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# Name: Ca, dtype: int64

# %%
data2[data2['Ca']==4]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Age, Sex, ChestPain, RestBP, Chol, Fbs, RestECG, MaxHR, ExAng, Oldpeak, Slope, Ca, Thal, AHD]
# Index: []

# %%
data2['Ca']=data2['Ca'].replace(4,np.nan)

# %%
data2.Ca.unique()
# Out:
# array([ 0.,  3.,  2.,  1., nan])

# %%
import matplotlib.pyplot as plt

# %%
x = data2.iloc[:,13]
y = data2.iloc[:,4]

plt.bar(x,y, color ='maroon',width = '0.4')
plt.xlabel('Target')
plt.ylabel('Chol')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11648/4114589848.py in <module>
#       2 y = data2.iloc[:,4]
#       3
# ----> 4 plt.bar(x,y, color ='maroon',width = '0.4')
#       5 plt.xlabel('Target')
#       6 plt.ylabel('Chol')
#
# NameError: name 'plt' is not defined

# %%
data2.boxplot(column=['Chol'])
# Out:
# <AxesSubplot:>

# %%
data2.boxplot(column=['Chol','Thal'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8680/2605147185.py in <module>
# ----> 1 data2.boxplot(column=['Chol','Thal'])
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     392     import matplotlib.pyplot as plt
#     393
# --> 394     ax = boxplot(
#     395         self,
#     396         column=column,
#
# ...

# %%
plt.boxplot(data2['Chol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20e48cd98b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20e48cd9fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20e48cd9520>],
#  'medians': [<matplotlib.lines.Line2D at 0x20e45578730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20e45578ac0>],
#  'means': []}
