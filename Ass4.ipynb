# %%
import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("heart.csv")

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
x= df.age

# %%
x
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
y= df.chol

# %%
y
# Out:
# 0       212
# 1       203
# 2       174
# 3       203
# 4       294
#        ...
# 1020    221
# 1021    258
# 1022    275
# 1023    254
# 1024    188
# Name: chol, Length: 1025, dtype: int64

# %%
plt.title("Scatter Graph to show Age Vs Chol")
plt.xlabel("AGE")
plt.ylabel("CHOL")
plt.scatter(x,y)

# %%
X=df.ca

# %%
X
# Out:
# 0       2
# 1       0
# 2       0
# 3       1
# 4       3
#        ..
# 1020    0
# 1021    1
# 1022    1
# 1023    0
# 1024    1
# Name: ca, Length: 1025, dtype: int64

# %%
Y= df.target

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
plt.title("Bar Graph to Show Ca Vs Target")
plt.xlabel("CA")
plt.ylabel("TARGET")
plt.bar(X,Y)
# Out:
# <BarContainer object of 1025 artists>

# %%
x= df.sex
x
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1020    1
# 1021    1
# 1022    1
# 1023    0
# 1024    1
# Name: sex, Length: 1025, dtype: int64

# %%
y=df.slope
y
# Out:
# 0       2
# 1       0
# 2       0
# 3       2
# 4       1
#        ..
# 1020    2
# 1021    1
# 1022    1
# 1023    2
# 1024    1
# Name: slope, Length: 1025, dtype: int64

# %%
plt.title("Line graph using Sex Vs Slope")
plt.xlabel("SEX")
plt.ylabel("SLOPE")
plt.plot(x,y)

# %%
x=df.age
y=df.trestbps

# %%
plt.title("Bar Graph to Show Age Vs Trestbps")
plt.xlabel("AGE")
plt.ylabel("TRESTBPS")
plt.pie(x,y)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
data= df.chol
data
# Out:
# 0       212
# 1       203
# 2       174
# 3       203
# 4       294
#        ...
# 1020    221
# 1021    258
# 1022    275
# 1023    254
# 1024    188
# Name: chol, Length: 1025, dtype: int64

# %%
plt.title("Bar Graph to Show Chol data")
plt.xlabel("Chol")
plt.boxplot(data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6578204590>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6575817690>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f657581f6d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f657581f190>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f657580ebd0>,
#   <matplotlib.lines.Line2D at 0x7f6575817150>]}
